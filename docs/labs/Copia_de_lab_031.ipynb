# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281_2023/blob/main/docs/labs/lab_031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # MAT281 - Laboratorio N°03

# %% [markdown]
# ## Problema 01
#
#
# <img src="https://imagenes.universia.net/gc/net/images/practicas-empleo/p/pr/pro/profesiones-con-el-avance-de-la-tecnologia.jpg" width="480" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `ocupation.csv`, el cual contiene información de distintos usuarios (edad ,sexo, profesión, etc.).
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd

# %%
# load data
url='https://drive.google.com/file/d/1SW1_vWBLd50COj4FbQdZenqAwA0nLDqC/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

df = pd.read_csv(url, sep="|" )
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:

# %% [markdown]
# 1.- ¿Cuál es el número de observaciones en el conjunto de datos?

# %%
print("El número de observaciones es ", df.shape[0])
# Out:
# El número de observaciones es  943

# %% [markdown]
# 2.- ¿Cuál es el número de columnas en el conjunto de datos?

# %%
print("El número de columnas es ", len(df.columns))
# Out:
# El número de columnas es  5

# %% [markdown]
# 3.- Imprime el nombre de todas las columnas

# %%
print("Estos son los nombres de las columnas: ")
for k in range(len(df.columns)):
  print(df.columns[k])
# Out:
# Estos son los nombres de las columnas:
# user_id
# age
# gender
# occupation
# zip_code

# %% [markdown]
# 4.- Imprima el índice del dataframe

# %%
print("Este es el índice del dataframe: ", df.index)
for k in range(df.shape[0]):
  print(df.index[k])

# %% [markdown]
# 5.- ¿Cuál es el tipo de datos de cada columna?

# %%
print("Este es el tipo de dato de cada columna: ")
for k in range(len(df.columns)):
  print(df.columns[k], ":" , str(df.dtypes[k]))
# Out:
# Este es el tipo de dato de cada columna:
# user_id : int64
# age : int64
# gender : object
# occupation : object
# zip_code : object

# %% [markdown]
# 6.- Describir el conjunto de datos (**hint**: .describe())

# %%
df.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %% [markdown]
# 7.- Imprimir solo la columna de **occupation**.

# educator
# healthcare
# administrator
# other
# salesman
# educator
# engineer
# healthcare
# programmer
# writer
# other
# other
# programmer
# other
# student
# librarian
# other
# educator
# librarian
# student
# student
# librarian
# homemaker
# other
# student
# student
# student
# other
# engineer
# technician
# administrator
# technician
# technician
# other
# administrator
# entertainment
# homemaker
# executive
# executive
# student
# administrator
# student
# executive
# student
# scientist
# educator
# other
# other
# other
# healthcare
# writer
# programmer
# technician
# technician
# educator
# writer
# student
# programmer
# marketing
# writer
# engineer
# other
# administrator
# other
# administrator
# other
# retired
# salesman
# librarian
# educator
# none
# student
# student
# student
# other
# student
# administrator
# scientist
# educator
# student
# other
# engineer
# administrator
# executive
# student
# student
# writer
# student
# student
# executive
# librarian
# programmer
# student
# student
# programmer
# student
# artist
# marketing
# administrator
# engineer
# engineer
# student
# administrator
# other
# technician
# educator
# programmer
# student
# educator
# programmer
# writer
# other
# writer
# administrator
# programmer
# writer
# administrator
# administrator
# educator
# other
# marketing
# healthcare
# salesman
# marketing
# other
# educator
# technician
# student
# other
# other
# other
# student
# librarian
# administrator
# student
# engineer
# librarian
# artist
# other
# engineer
# artist
# engineer
# librarian
# writer
# programmer
# other
# technician
# writer
# other
# executive
# artist
# artist
# student
# entertainment
# artist
# doctor
# writer
# librarian
# engineer
# doctor
# lawyer
# student
# engineer
# student
# technician
# other
# administrator
# writer
# student
# librarian
# marketing
# administrator
# educator
# other
# retired
# student
# executive
# student
# programmer
# artist
# other
# scientist
# programmer
# student
# student
# executive
# student
# administrator
# scientist
# student
# other
# other
# educator
# administrator
# student
# marketing
# engineer
# librarian
# engineer
# other
# student
# student
# scientist
# technician
# student
# administrator
# other
# student
# educator
# librarian
# writer
# other
# homemaker
# other
# retired
# executive
# artist
# educator
# student
# other
# librarian
# other
# librarian
# educator
# healthcare
# writer
# other
# student
# other
# entertainment
# engineer
# student
# scientist
# other
# artist
# student
# administrator
# student
# other
# salesman
# entertainment
# programmer
# student
# scientist
# scientist
# educator
# educator
# student
# engineer
# doctor
# other
# educator
# technician
# student
# administrator
# student
# librarian
# student

# %% [markdown]
# 8.- ¿Cuántas ocupaciones diferentes hay en este conjunto de datos?

# %%
print("Hay", len(df['occupation'].unique()), "ocupaciones diferentes")
# Out:
# Hay 21 ocupaciones diferentes

# %% [markdown]
# 9.- ¿Cuál es la ocupación más frecuente?

# %%
print("La ocupación más frecuente es ",df['occupation'].value_counts().index[0], "con ", df['occupation'].value_counts()[0], "usuarios")
# Out:
# La ocupación más frecuente es  student con  196 usuarios

# %% [markdown]
# 10.- ¿Cuál es la edad media de los usuarios?

# %%
print("La edad media de los usuarios es", int(df['age'].mean()))
# Out:
# La edad media de los usuarios es 34

# %% [markdown]
# 11.- ¿Cuál es la edad con menos ocurrencia?

# %%
print("La edad con menos ocurrencia es ", df['age'].value_counts().index[-1])
# Out:
# La edad con menos ocurrencia es  73
